# %% [markdown]
# <a href="https://colab.research.google.com/github/Davaxelle/Machine-Learning-Assignment-1/blob/main/Machine_learning_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Machine Learning Problem Statement (data):
#
# The machine learning tool can help quickly find students in the district of New York with high Maths score and maybe genuis in Maths.
#
#
# The tool can help quickly analyze student with flaws in Maths that need tutoring or improvement in making better results.
#
#
# The tool will be excellent in making selection of smart kids by analyzing the results and approximatively detecting high IQ level based on results.

# %% [markdown]
# Machine Learning Problem statement(data_1):
#
# The Machine Learning tool may help civil rights agencies predict any discrimintaion in the claimant file application process based on race , gender, ethnicity or affiliation. It wil will help tne agencies target the people succeptible to discrimination.
#
#   The machine learning tool will help the data team streamline information request from the claimants and also identify any discrepancies.
#
#   This could lead to more solved cases and filtrate any incomplete or disquaified files in a short period of time for the claimants to have an updated feedback of their cases in a timely manner.

# %%
#Import Pandas Library
import pandas as pd

# %%
data = pd.read_csv('/content/2006_-_2012__Math_Test_Results_-_District_-_All_Students.csv')
data_1= pd.read_csv('/content/Appeals_Filed_In_2017.csv')

# %%
-#Understanding of the dataset
data.head()
# Out:
#    District Grade  Year  ... Pct Level 4  Num Level 3 and 4  Pct Level 3 and 4
# 0         1     3  2006  ...        22.3                693               74.0
# 1         1     3  2007  ...        22.8                702               84.0
# 2         1     3  2008  ...        24.8                751               87.1
# 3         1     3  2009  ...        26.5                840               91.9
# 4         1     3  2010  ...        27.8                520               60.0
#
# [5 rows x 16 columns]

# %%
data_1.head()
# Out:
#       Appeal Type Appeal Subtype  ... Extension Acronym
# 0  Waiting for DQ            NaN  ...       NaN    NYPD
# 1      Section 50      Character  ...       NaN    NYPD
# 2      Section 50          Score  ...       NaN    DCAS
# 3      Section 50     Timeliness  ...       NaN    DCAS
# 4      Section 50      Character  ...       NaN    NYPD
#
# [5 rows x 11 columns]

# %%
data_1.max()
# Out:
# Appeal Type               Waiting for DQ
# Agency         Transit Authority - NYCTA
# Status                              Open
# Date Filed                    12/29/2017
# Exam No.                            8213
# Extension                            NaN
# Acronym                              OTH
# dtype: object

# %%
data.mean()
# Out:
# District               16.500000
# Year                 2009.000000
# Number Tested        3827.982143
# Mean Scale Score      672.262755
# Num Level 1           356.196429
# Pct Level 1             9.805548
# Num Level 2          1012.852041
# Pct Level 2            27.356059
# Num Level 3          1648.980867
# Pct Level 3            42.640561
# Num Level 4           809.952806
# Pct Level 4            20.196875
# Num Level 3 and 4    2458.933673
# Pct Level 3 and 4      62.838138
# dtype: float64

# %%
data.min()
# Out:
# District                        1
# Grade                           3
# Year                         2006
# Demographic          All Students
# Number Tested                 643
# Mean Scale Score              615
# Num Level 1                     1
# Pct Level 1                   0.1
# Num Level 2                    11
# Pct Level 2                   0.6
# Num Level 3                   151
# Pct Level 3                    15
# Num Level 4                     9
# Pct Level 4                   0.6
# Num Level 3 and 4             198
# Pct Level 3 and 4            15.6
# dtype: object

# %%
data.Year.min()
# Out:
# 2006

# %%
#Read Headers
print(data.columns)
# Out:
# Index(['District', 'Grade', 'Year', 'Demographic', 'Number Tested',
#        'Mean Scale Score', 'Num Level 1', 'Pct Level 1', 'Num Level 2',
#        'Pct Level 2', 'Num Level 3', 'Pct Level 3', 'Num Level 4',
#        'Pct Level 4', 'Num Level 3 and 4', 'Pct Level 3 and 4'],
#       dtype='object')

# %%
data.max()
# Out:
# District                       32
# Grade                  All Grades
# Year                         2012
# Demographic          All Students
# Number Tested               26626
# Mean Scale Score              723
# Num Level 1                  5120
# Pct Level 1                  42.1
# Num Level 2                  9825
# Pct Level 2                  53.5
# Num Level 3                 14658
# Pct Level 3                  72.7
# Num Level 4                  8117
# Pct Level 4                    72
# Num Level 3 and 4           22481
# Pct Level 3 and 4            99.3
# dtype: object

# %%
#Cleaning the dataset
data.isnull()
# Out:
#       District  Grade   Year  ...  Pct Level 4  Num Level 3 and 4  Pct Level 3 and 4
# 0        False  False  False  ...        False              False              False
# 1        False  False  False  ...        False              False              False
# 2        False  False  False  ...        False              False              False
# 3        False  False  False  ...        False              False              False
# 4        False  False  False  ...        False              False              False
# ...        ...    ...    ...  ...          ...                ...                ...
# 1563     False  False  False  ...        False              False              False
# 1564     False  False  False  ...        False              False              False
# 1565     False  False  False  ...        False              False              False
# 1566     False  False  False  ...        False              False              False
# ...

# %%
data_1.isnull()
# Out:
#       Appeal Type  Appeal Subtype  Agency  ...  Expiration  Extension  Acronym
# 0           False            True   False  ...        True       True    False
# 1           False           False   False  ...       False       True    False
# 2           False           False   False  ...       False       True    False
# 3           False           False   False  ...       False       True    False
# 4           False           False   False  ...       False       True    False
# ...           ...             ...     ...  ...         ...        ...      ...
# 1260        False           False   False  ...       False       True    False
# 1261        False           False   False  ...       False       True    False
# 1262        False           False   False  ...       False       True    False
# 1263        False           False   False  ...        True       True    False
# 1264        False           False   False  ...        True       True    False
#
# ...

# %%
data_1.isnull().sum()
# Out:
# Appeal Type          0
# Appeal Subtype     162
# Agency               0
# Status               0
# Date Filed           0
# Date Closed        471
# Exam No.           201
# Title              201
# Expiration         470
# Extension         1265
# Acronym              0
# dtype: int64

# %%
#Handling the problem of missing values
missing_values= ['N/a','na','np.nan']
data_1=pd.read_csv('/content/Appeals_Filed_In_2017.csv',na_values=missing_values)

# %%
data_1.isnull().sum()
# Out:
# Appeal Type          0
# Appeal Subtype     162
# Agency               0
# Status               0
# Date Filed           0
# Date Closed        471
# Exam No.           201
# Title              201
# Expiration         470
# Extension         1265
# Acronym              0
# dtype: int64

# %%
data_1
# Out:
#          Appeal Type            Appeal Subtype  ... Extension Acronym
# 0     Waiting for DQ                       NaN  ...       NaN    NYPD
# 1         Section 50                 Character  ...       NaN    NYPD
# 2         Section 50                     Score  ...       NaN    DCAS
# 3         Section 50                Timeliness  ...       NaN    DCAS
# 4         Section 50                 Character  ...       NaN    NYPD
# ...              ...                       ...  ...       ...     ...
# 1260      Section 50                     Psych  ...       NaN    NYPD
# 1261      Section 50                   Medical  ...       NaN    FDNY
# 1262      Section 50                Timeliness  ...       NaN    DCAS
# 1263      Section 50  Education and Experience  ...       NaN    DCAS
# 1264      Section 50  Education and Experience  ...       NaN    DCAS
#
# [1265 rows x 11 columns]

# %%
data_1.fillna(0)
# Out:
#          Appeal Type            Appeal Subtype  ... Extension Acronym
# 0     Waiting for DQ                         0  ...       0.0    NYPD
# 1         Section 50                 Character  ...       0.0    NYPD
# 2         Section 50                     Score  ...       0.0    DCAS
# 3         Section 50                Timeliness  ...       0.0    DCAS
# 4         Section 50                 Character  ...       0.0    NYPD
# ...              ...                       ...  ...       ...     ...
# 1260      Section 50                     Psych  ...       0.0    NYPD
# 1261      Section 50                   Medical  ...       0.0    FDNY
# 1262      Section 50                Timeliness  ...       0.0    DCAS
# 1263      Section 50  Education and Experience  ...       0.0    DCAS
# 1264      Section 50  Education and Experience  ...       0.0    DCAS
#
# [1265 rows x 11 columns]

# %%
#Exploratory analysis
#Describe data
data.describe()
# Out:
#           District         Year  ...  Num Level 3 and 4  Pct Level 3 and 4
# count  1568.000000  1568.000000  ...        1568.000000        1568.000000
# mean     16.500000  2009.000000  ...        2458.933673          62.838138
# std       9.236038     2.000638  ...        3107.392459          17.362835
# min       1.000000  2006.000000  ...         198.000000          15.600000
# 25%       8.750000  2007.000000  ...         862.500000          48.350000
# 50%      16.500000  2009.000000  ...        1570.000000          63.400000
# 75%      24.250000  2011.000000  ...        2378.000000          76.800000
# max      32.000000  2012.000000  ...       22481.000000          99.300000
#
# [8 rows x 14 columns]

# %%
data_1.describe()
# Out:
#           Exam No.  Extension
# count  1265.000000     1265.0
# mean   4476.063241        0.0
# std    2452.276463        0.0
# min       0.000000        0.0
# 25%    3308.000000        0.0
# 50%    5039.000000        0.0
# 75%    6325.000000        0.0
# max    8213.000000        0.0

# %%
#Data correlation
data.corr()
# Out:
#                    District      Year  ...  Num Level 3 and 4  Pct Level 3 and 4
# District           1.000000  0.000000  ...           0.187911           0.225172
# Year               0.000000  1.000000  ...          -0.032951          -0.137756
# Number Tested      0.139614 -0.009328  ...           0.960859           0.067891
# Mean Scale Score   0.216659  0.477304  ...           0.175850           0.692965
# Num Level 1       -0.023032 -0.094142  ...           0.593882          -0.317555
# Pct Level 1       -0.231191 -0.155454  ...          -0.225217          -0.898417
# Num Level 2        0.047268  0.082662  ...           0.733236          -0.229003
# Pct Level 2       -0.202964  0.285276  ...          -0.237760          -0.971227
# Num Level 3        0.153594 -0.086676  ...           0.977700           0.181807
# Pct Level 3        0.088628 -0.399952  ...           0.155010           0.690865
# Num Level 4        0.227296  0.063929  ...           0.931075           0.333050
# ...

# %%
data_1.corr()
# Out:
#            Exam No.  Extension
# Exam No.        1.0        NaN
# Extension       NaN        NaN

# %%
#Data Vizualisation
data.plot.hist(bins=20)

# %%
data.plot.area()

# %%
data_1.plot.box()

# %%
data_1.plot.area()
